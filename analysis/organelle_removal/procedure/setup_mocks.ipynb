# %%
import numpy as np
import os
import pandas as pd
import shutil
import urllib.request

from qiime2 import Artifact
from qiime2.plugins.dada2.methods import denoise_single

# %%
def download_file(url, local_filepath):
    """Download a file from a remote url and save to a local filepath
    
    url - the web address of the file you want to download as a string
    local_filepath - the local filepath to which the file will be saved
    """
    print(f"Downloading file: {url}")
    with urllib.request.urlopen(url) as response, open(local_filepath, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)
    
    print(f"Saved to local filepath: {local_filepath}")

# %%
def make_directory(path):
    """Make a directory, but proceed without errors if it fails
    path -- the path to the directory (e.g. "../output/taxonomy_references")
    """
    try:
        os.mkdir(path)
    except OSError:
        print (f"Creation of directory {path} failed")
    else:
        print (f"Created the directory {path}")

# %%
working_dir=os.path.abspath('../')
mock_dir=working_dir+'/output/mock_communities'
metadata_url_base='https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-'

# %%
mocks=[12, 13, 14, 15, 16, 18, 19, 20, 21, 22]

# %%
#download the forward reads, import into qiime2, and create
#sequence and feature table artifacts
#this loop could take a while, depending on the power of your
#cpu and your download speed
if not os.path.exists(mock_dir):
    print(f'Creating mock directory {mock_dir}')
    make_directory(mock_dir)
for mock in mocks:
    mock_folder=mock_dir+'/mock_'+str(mock)
    if not os.path.exists(mock_folder):
        print(f'Creating mock folder {mock_folder}')
        make_directory(mock_folder)
    metadata_url=metadata_url_base+str(mock)+'/dataset-metadata.tsv'
    metadata_filepath=mock_dir+'/metadata.tsv'
    sample_metadata_url=metadata_url_base+str(mock)+'/sample-metadata.tsv'
    sample_metadata_filepath=mock_dir+'/sample_metadata.tsv'
    download_file(metadata_url, metadata_filepath)
    download_file(sample_metadata_url, sample_metadata_filepath)
    metadata=pd.read_csv(metadata_filepath, sep='\t')
    sample_metadata=pd.read_csv(sample_metadata_filepath, sep='\t')
    sample_name=sample_metadata['SampleID'][0]
    forward_url=metadata['value'].values[2]
    forward_filepath=mock_folder+'/1_1_L001_R1_001.fastq.gz'
    #reverse_url=metadata['value'].values[3]
    #reverse_filepath=mock_folder+'/'+str(mock)+'_reverse.fastq.gz'
    #index_url=metadata['value'].values[4]
    #index_filepath=mock_folder+'/'+str(mock)+'_index.'
    download_file(forward_url, forward_filepath)
    #download_file(reverse_url, reverse_filepath)
    #importing a fastq file into qiime2 requires a manifest file and a metadata.yml file
    if not os.path.exists(mock_folder+'/MANIFEST'):
        with open(mock_folder+'/MANIFEST', 'w') as file:
            file.write('sample-id,filename,direction\n'+'sample1,'+forward_filepath+',forward')
    if not os.path.exists(mock_folder+'/metadata.yml'):
        with open(mock_folder+'/metadata.yml', 'w') as file:
            pass
    #now we need to import them into qiime
    seqs = Artifact.import_data('SampleData[SequencesWithQuality]', '../output/mock_communities/mock_'+str(mock))
    seqs.save(mock_folder+'/mock_'+str(mock)+'_sequences.qza')
    table, sequences, stats=denoise_single(seqs, 0, n_threads=0)
    table.save(mock_folder+'/mock_'+str(mock)+'_ft.qza')
    sequences.save(mock_folder+'/mock_'+str(mock)+'_rep_seqs.qza')
    print('mock', mock, 'imported\n')
# Out:
# Creating mock directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_12
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_12
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-12/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-12/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-12/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_12/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-jjsuduaa/ed8f0304-ab58-468e-a001-c50bf7c67749/data /tmp/tmpju4nca60/output.tsv.biom /tmp/tmpju4nca60/track.tsv /tmp/tmpju4nca60 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 12 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_13
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_13
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-13/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-13/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-13/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_13/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-ssxhoas5/cf9e7237-eb94-4b4d-9b94-d0b02870bfa3/data /tmp/tmp_65_a9ur/output.tsv.biom /tmp/tmp_65_a9ur/track.tsv /tmp/tmp_65_a9ur 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 13 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_14
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_14
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-14/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-14/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-14/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_14/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-h_p2zb5q/c919744b-1f0b-40c4-98be-a9fbfa5b22e3/data /tmp/tmpu70f0k3r/output.tsv.biom /tmp/tmpu70f0k3r/track.tsv /tmp/tmpu70f0k3r 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 14 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_15
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_15
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-15/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-15/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-15/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_15/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-k9ae6dt7/b41e04ef-ca58-498f-be21-e900da79e8ff/data /tmp/tmpco7f0enx/output.tsv.biom /tmp/tmpco7f0enx/track.tsv /tmp/tmpco7f0enx 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 15 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_16
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_16
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-16/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-16/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-16/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_16/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-39c7ucsq/1ca241b4-0feb-4bd2-bb1c-dcf74ce188cd/data /tmp/tmplrapencj/output.tsv.biom /tmp/tmplrapencj/track.tsv /tmp/tmplrapencj 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
# mock 16 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_18
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_18
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-18/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-18/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-18/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_18/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-4xhxo3ab/c92daa12-99bc-400e-9078-612926b1b18f/data /tmp/tmphnn4u9h3/output.tsv.biom /tmp/tmphnn4u9h3/track.tsv /tmp/tmphnn4u9h3 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 18 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_19
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_19
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-19/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-19/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-19/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_19/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-tdciaz3b/b810f35a-435d-4e5c-85b0-04730e39d8da/data /tmp/tmph47qo43p/output.tsv.biom /tmp/tmph47qo43p/track.tsv /tmp/tmph47qo43p 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 19 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_20
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_20
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-20/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-20/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-20/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_20/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-ip8jlqly/814cc117-faf3-492e-b1ea-84aa8f01f476/data /tmp/tmpnmam40ll/output.tsv.biom /tmp/tmpnmam40ll/track.tsv /tmp/tmpnmam40ll 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 20 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_21
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_21
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-21/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-21/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-21/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_21/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-qgb3zgqe/8354eefa-48f2-479c-b480-50725e75da66/data /tmp/tmp683cnmcw/output.tsv.biom /tmp/tmp683cnmcw/track.tsv /tmp/tmp683cnmcw 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 21 imported
#
# Creating mock folder /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_22
# Created the directory /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_22
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-22/dataset-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/metadata.tsv
# Downloading file: https://github.com/caporaso-lab/mockrobiota/raw/master/data/mock-22/sample-metadata.tsv
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/sample_metadata.tsv
# Downloading file: https://s3-us-west-2.amazonaws.com/mockrobiota/latest/mock-22/mock-forward-read.fastq.gz
# Saved to local filepath: /mnt/c/Users/Dylan/Documents/zaneveld/2_14_gcmp/GCMP_Global_Disease/analysis/organelle_removal/output/mock_communities/mock_22/1_1_L001_R1_001.fastq.gz
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada_single.R /tmp/qiime2-archive-fpzvdppb/66567855-e2ef-41eb-a6eb-6ad3c9f4ea60/data /tmp/tmpsqjihi0_/output.tsv.biom /tmp/tmpsqjihi0_/track.tsv /tmp/tmpsqjihi0_ 0 0 2.0 2 Inf independent consensus 1.0 0 1000000 NULL 16
#
# mock 22 imported
